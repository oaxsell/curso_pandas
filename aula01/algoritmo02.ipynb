# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/dataset_ruido.csv', sep=',')

# %%
df.head()
# Out:
#    numero do dia  nivel ruido (dB)
# 0              1                85
# 1              2                92
# 2              3                95
# 3              4                98
# 4              5                99

# %%
# Calcular a média da coluna 'nivel ruido (dB)'
df['nivel ruido (dB)'].mean()
# Out:
# np.float64(108.44444444444444)
