# %% [markdown]
# Codigo para leitura do dataset

# %%
import pandas as pd

# %%
df_total = pd.read_csv('datasets/tempo_salarios.csv')

# %%
df_total.head()
# Out:
#    AnosdeExperiencia  Salario
# 0                1.1  39343.0
# 1                1.3  46205.0
# 2                1.5  37731.0
# 3                2.0  43525.0
# 4                2.2  39891.0

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AnosdeExperiencia  30 non-null     float64
#  1   Salario            30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
print(f"Qtd linhas: {len(df_total)}")
# Out:
# Qtd linhas: 30
